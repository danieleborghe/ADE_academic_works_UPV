# %% [markdown]
# <div style="display: flex; align-items: center;">
#     <div style="max-width: 300px;">
#         <img src="marca_UPV_principal_negro150.png" />
#     </div>
#     <div style="max-width: 400px; padding: 20px">
#         <img src="ETSInf_PRINCIPAL_V-horizontal.png"/>
#     </div>
#     <div>
#         Daniele Borghesi</br>
#         Francesco Pio Capoccello
#     </div>
# </div>
#
# # Educational Data Analysis
# ## ASSIGNMENT 2: Dimensionality Reduction
# ----
# ## PART 2
# ### Clustering
# ----

# %% [markdown]
# ## Preliminary operations

# %%
# import main libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from factor_analyzer import FactorAnalyzer
import seaborn as sns
from sklearn.cluster import KMeans
sns.set(style="white")

# %%
# import reflex C dataset
df_reflex_C = pd.read_excel("reflex_c.xlsx")
# get job values features
df_job_values = df_reflex_C.loc[:, "Work_Autonomy":]
# convert job values to np array for clustering
np_job_values = np.array(df_job_values)

df_job_values
# Out:
#       Work_Autonomy  Job_Stability  Opportunity_Things  High_Income  \
# 0                 4              5                   5            5
# 1                 4              4                   4            3
# 2                 4              5                   4            4
# 3                 4              4                   4            4
# 4                 2              4                   4            3
# ...             ...            ...                 ...          ...
# 2112              4              3                   5            4
# 2113              3              4                   5            5
# 2114              5              5                   5            4
# 2115              5              5                   5            5
# 2116              3              4                   5            4
#
#       Meeting_Challenges  Good_Prospects  Have_Yourself  \
# 0                      4               5              5
# ...

# %% [markdown]
# ## Factor transformation

# %%
# fit factor analysis model with the 3 factors obtained
n_factors = 3
factor_analyzer = FactorAnalyzer(n_factors, rotation=None)
factor_analyzer.fit(df_job_values)

# calculate factor scores
factor_scores = factor_analyzer.transform(df_job_values)
factor_scores
# Out:
# array([[ 0.61410216,  0.47484798, -0.60097017],
#        [-0.49784275,  0.75419182,  1.12526861],
#        [-0.03532596,  0.43031594, -0.00823213],
#        ...,
#        [ 0.37189515,  0.37536427,  0.38233261],
#        [ 0.00800819, -2.11065873, -1.18317476],
#        [-0.43031609, -0.18819035,  0.0044414 ]])

# %% [markdown]
# ## Hierarchical clustering

# %% [markdown]
# ### Reduced dataset

# %%
# calculate hierarchical clustering matrix with Ward method
linkage_matrix = linkage(factor_scores, method='ward', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (Ward linkage)')

plt.savefig("hierarchical_factors_ward.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with single linkage
linkage_matrix = linkage(factor_scores, method='single', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (single linkage)')

plt.savefig("hierarchical_factors_single.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with complete linkage
linkage_matrix = linkage(factor_scores, method='complete', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (complete linkage)')

plt.savefig("hierarchical_factors_complete.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with average linkage
linkage_matrix = linkage(factor_scores, method='average', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (average linkage)')

plt.savefig("hierarchical_factors_average.pdf", format="pdf")

plt.show()

# %% [markdown]
# ### Original dataset

# %%
# calculate hierarchical clustering matrix with Ward method
linkage_matrix = linkage(np_job_values, method='ward', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (Ward linkage)')

plt.savefig("hierarchical_original_ward.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with single linkage
linkage_matrix = linkage(np_job_values, method='single', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (single linkage)')

plt.savefig("hierarchical_original_single.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with complete linkage
linkage_matrix = linkage(np_job_values, method='complete', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (complete linkage)')

plt.savefig("hierarchical_original_complete.pdf", format="pdf")

plt.show()

# %%
# calculate hierarchical clustering matrix with average linkage
linkage_matrix = linkage(np_job_values, method='average', metric='euclidean')

# plot hierachical clustering dendrogram
plt.figure(figsize=(14, 5))

dendrogram(linkage_matrix)

plt.xlabel('Data Points')
plt.ylabel('Distance')
plt.title('Hierarchical Clustering Dendrogram (average linkage)')

plt.savefig("hierarchical_original_average.pdf", format="pdf")

plt.show()

# %% [markdown]
# ## K-Means

# %%
# set the number of clusters
n_clusters = 4

# create K-Means instance
kmeans = KMeans(n_clusters = n_clusters, n_init="auto")

# fit K-Means
kmeans.fit(factor_scores)

# get clustering labels
labels = kmeans.labels_
# get clustering centers
cluster_centers = kmeans.cluster_centers_

# plot the clustering scatterplot
plt.figure(figsize=(14, 5))

sns.scatterplot(x=factor_scores[:, 0], y=factor_scores[:, 1], hue=labels, palette='viridis')
sns.scatterplot(x=cluster_centers[:, 0], y=cluster_centers[:, 1], color='red', marker='X', s=100, label='Cluster Centers')

plt.xlabel('Factor 1')
plt.ylabel('Factor 2')
plt.title('K-Means Clustering (factors)')
plt.legend()

plt.savefig("kmeans_factors_4k.pdf", format="pdf")

plt.show()
# Out:
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
# set the number of clusters
n_clusters = 4

# create K-Means instance
kmeans = KMeans(n_clusters = n_clusters, n_init="auto")

# fit K-Means
kmeans.fit(np_job_values)

# get clustering labels
labels = kmeans.labels_
# get clustering centers
cluster_centers = kmeans.cluster_centers_

# plot the clustering scatterplot
plt.figure(figsize=(14, 5))

sns.scatterplot(x=np_job_values[:, 0], y=np_job_values[:, 1], hue=labels, palette='viridis')
sns.scatterplot(x=cluster_centers[:, 0], y=cluster_centers[:, 1], color='red', marker='X', s=100, label='Cluster Centers')

plt.xlabel('Factor 1')
plt.ylabel('Factor 2')
plt.title('K-Means Clustering (original)')
plt.legend()

plt.savefig("kmeans_factors_4k.pdf", format="pdf")

plt.show()
# Out:
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/danieleborghesi/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
